# %%
import numpy as np
import matplotlib.pyplot as plt
import algorithms as a
import force_functions as f

# %config Completer.use_jedi = False

# %%
r1_0 = np.array([1./3., 0., 0.], dtype=np.float32)
r2_0 = -r1_0
p1_0 = np.array([-6./7., 3./7., -2./7.], dtype=np.float32)
p2_0 = -p1_0

# %%
t_sim = 10
dt = 1e-2

# %%
r1_dumb, r2_dumb, p1_dumb, p2_dumb, t_dumb = a.velocity_verlet(r1_0, r2_0, 
                                                               p1_0, p2_0, 
                                                               t_sim, dt, 
                                                               f.dumbbell_force)

# %%
plt.plot(r1_dumb[:,0], r1_dumb[:,1])
plt.plot(r2_dumb[:,0], r2_dumb[:,1])

# %%
r1_0 = np.array([1./3., 0., 0.], dtype=np.float32)
r2_0 = -r1_0
p1_0 = np.array([-6./7., 3./7., -2./7.], dtype=np.float32)
p2_0 = -p1_0

# %%
r1_FENE, r2_FENE, p1_FENE, p2_FENE, t_FENE = a.velocity_verlet(r1_0, r2_0, p1_0, p2_0, t_sim, dt, f.FENE_force)

# %%
plt.plot(r1_FENE[:,0], r1_FENE[:,1])
plt.plot(r2_FENE[:,0], r2_FENE[:,1])

# %%
r1_0 = np.array([1./3., 0., 0.], dtype=np.float32)
r2_0 = -r1_0
p1_0 = np.array([-6./7., 3./7., -2./7.], dtype=np.float32)
p2_0 = -p1_0

# %%
t_sim = 10
k = 2
dt = 4**(-k)
l = 0.1931833275037836

# %%
r1_dumb_BABAB, r2_dumb_BABAB, p1_dumb_BABAB, p2_dumb_BABAB, t_dumb_BABAB = a.velocity_verlet_BABAB(r1_0, r2_0, 
                                                                                                   p1_0, p2_0, 
                                                                                                   t_sim, dt, 
                                                                                                   f.dumbbell_force, l)

# %%
plt.plot(r1_dumb_BABAB[:,0], r1_dumb_BABAB[:,1])
plt.plot(r2_dumb_BABAB[:,0], r2_dumb_BABAB[:,1])

# %%
r1_0 = np.array([1./3., 0., 0.], dtype=np.float32)
r2_0 = -r1_0
p1_0 = np.array([-6./7., 3./7., -2./7.], dtype=np.float32)
p2_0 = -p1_0

# %%
r1_FENE_BABAB, r2_FENE_BABAB, p1_FENE_BABAB, p2_FENE_BABAB, t_FENE_BABAB = a.velocity_verlet_BABAB(r1_0, r2_0, 
                                                                                                   p1_0, p2_0, 
                                                                                                   t_sim, dt, 
                                                                                                   f.FENE_force, l)

# %%
plt.plot(r1_FENE_BABAB[:,0], r1_FENE_BABAB[:,1])
plt.plot(r2_FENE_BABAB[:,0], r2_FENE_BABAB[:,1])
